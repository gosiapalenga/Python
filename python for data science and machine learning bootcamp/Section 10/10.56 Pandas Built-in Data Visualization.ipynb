# %%
# df2.plot.area(alpha=0.4)    # alpha --> transparency of the colors

# df1.plot.hist()                                        histogram

# df2.plot.bar(stacked=True)                             bar plot

# df1.plot.line(y='B', use_index=True, figsize=(18,3))   plotting time series

# df1.plot.scatter(x='A', y='B')                         scatter
# df1.plot.scatter(x='A', y='B',c='C',cmap='coolwarm', figsize=(10,6))     scatter 3 values

# df1.plot.box()                                         boxplot

# df.plot.hexbin(x='a', y='b', gridsize=25)              hexplot

# df2.plot.kde()                                         kde

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)
df1.head()                                 # It's Time Series as the index is a date
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# get histogram for all values in df1 A column

df1['A'].hist(bins=30, figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
# Plotting stock info

df1.plot.line(y='B', use_index=True, figsize=(18,3))
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B',c='C',cmap='coolwarm', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
# KDE

df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
