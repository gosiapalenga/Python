# %%
# sns.set_style(style='white')  # background

# sns.despine(right=True,top=True)  # remove right and top axes. Call after your plotting function!!!!!!!!!!!!!!

# plt.figure(figsize=(10,8))

# sns.set_context('poster')
# sns.set_context('notebook')  # size of the plot

# sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='seismic')     # colors palette

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style(style='white')  # background

sns.countplot(x='sex', data=tips)

sns.despine(right=True,top=True)  # remove right and top axes. Call after your plotting function!!!!!!!!!!!!!!

# %%
# Size and aspects

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x='sex', data=tips)
sns.despine(right=True,top=True)

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '157'), Text(0, 0, '87')]

# %%
# Scale and context

# %%
#plt.figure(figsize=(10,8))
sns.set_context('poster')

ax = sns.countplot(x='sex', data=tips)
sns.despine(right=True,top=True)

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '157'), Text(0, 0, '87')]

# %%
# Pallets and colors

# %%
sns.set_context('notebook')

sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='seismic')
