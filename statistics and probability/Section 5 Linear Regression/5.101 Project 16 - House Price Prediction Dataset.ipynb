# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# %%
data = pd.read_csv('california.csv')

data.head()
# Out:
#      long    lat  median_age  tot_rooms  tot_bedrooms   pop  households  \
# 0 -114.31  34.19          15       5610          1280  1014         470
# 1 -114.47  34.40          19       7650          1901  1129         463
# 2 -114.56  33.69          17        720           174   333         117
# 3 -114.57  33.64          14       1501           337   515         226
# 4 -114.57  33.57          20       1454           326   624         262
#
#    median_income  median_house_value
# 0         1.4936               66900
# 1         1.8200               80100
# 2         1.6509               85700
# 3         3.1917               73400
# 4         1.9250               65500

# %%
data.shape
# Out:
# (17000, 9)

# %%
data.isnull().sum()
# Out:
# long                  0
# lat                   0
# median_age            0
# tot_rooms             0
# tot_bedrooms          0
# pop                   0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
colormap = sns.color_palette('Greens', 12)
sns.set (rc = {'figure.figsize':(20, 10)})

sns.heatmap(data.corr(), cmap=colormap, annot=True, annot_kws={"fontsize":16})
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['long', 'lat', 'median_age', 'tot_rooms', 'tot_bedrooms', 'pop',
#        'households', 'median_income', 'median_house_value'],
#       dtype='object')

# %%
X = data[['long', 'lat', 'median_age', 'tot_rooms', 'tot_bedrooms', 'pop',
       'households', 'median_income']]

# %%
y = data['median_house_value']

# %%
X.shape
# Out:
# (17000, 8)

# %%
y.shape
# Out:
# (17000,)

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (17000, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6533423954779334

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 50544.777869061065
